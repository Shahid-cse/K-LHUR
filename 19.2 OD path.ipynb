# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import random
from typing import List, Dict, Any, Tuple, Set
from multiprocessing import Pool, cpu_count
import itertools
from tqdm import tqdm

import os
import time
import torch

# %%
output_dir = 'D:/Thesis/files_output_dir/output_utilization/'

# %%
level1_road_history_workday_utility = pd.read_csv(output_dir + 'level1_road_history_workday_utilization_tune.csv')
level2_road_history_workday_utility = pd.read_csv(output_dir + 'level2_road_history_workday_utilization_tune.csv')

# %%
# Read the graph back from the GraphML file
G = nx.read_graphml(output_dir + "graph_1.graphml")
len(G.nodes())
# Out:
# 21143

# %%
def graph_weight_update_road_utility(road_data, graph, time_slot=48):
    # Filter for the specific time slot
    time_slot_data = road_data[
        road_data['time'] == time_slot
    ]
    
    # Create a mapping of road_id to inv_utilization
    road_weights = dict(zip(
        time_slot_data['road_id'],
        time_slot_data['inv_utilization']
    ))
    
    # Update graph edge weights
    for u, v, data in graph.edges(data=True):
        road_id = data.get('road_id')
        if road_id in road_weights:
            graph[u][v]['weight'] = road_weights[road_id]
    
    return graph

# %%
road_history_workday_utility = pd.concat([
        level1_road_history_workday_utility[['time','road_id','utilization', 'inv_utilization']],
        level2_road_history_workday_utility[['time','road_id','utilization', 'inv_utilization']]
    ], ignore_index=True)

# %%
G_workday_48 = graph_weight_update_road_utility(road_history_workday_utility, G.copy(), time_slot=48)

# %%
def identify_potential_origins_destinations(G):
    # Calculate node metrics
    degree_cent = nx.degree_centrality(G)
    betweenness_cent = nx.betweenness_centrality(G, weight='weight')
    
    # Get average metrics
    avg_degree = sum(degree_cent.values()) / len(degree_cent)
    avg_betweenness = sum(betweenness_cent.values()) / len(betweenness_cent)

    print('avg_degree:', avg_degree)
    print('avg_betweenness', avg_betweenness)
    
    # Identify potential origins (high degree, moderate-high betweenness)
    origins = [
        node for node in G.nodes()
        if (degree_cent[node] > avg_degree and 
            betweenness_cent[node] > avg_betweenness * 0.5)
    ]
    
    # Identify potential destinations (high betweenness, any degree)
    destinations = [
        node for node in G.nodes()
        if betweenness_cent[node] > avg_betweenness
    ]
    
    # Ensure minimum number of OD nodes
    min_od_nodes = min(50, len(G.nodes()) // 4)  # at least 50 nodes or 25% of network
    
    if len(origins) < min_od_nodes:
        # Add more nodes based on degree centrality
        additional_nodes = sorted(
            [(n, degree_cent[n]) for n in G.nodes() if n not in origins],
            key=lambda x: x[1],
            reverse=True
        )[:min_od_nodes - len(origins)]
        origins.extend([n for n, _ in additional_nodes])
    
    if len(destinations) < min_od_nodes:
        # Add more nodes based on betweenness centrality
        additional_nodes = sorted(
            [(n, betweenness_cent[n]) for n in G.nodes() if n not in destinations],
            key=lambda x: x[1],
            reverse=True
        )[:min_od_nodes - len(destinations)]
        destinations.extend([n for n, _ in additional_nodes])
    
    return list(set(origins)), list(set(destinations)), degree_cent, betweenness_cent

# %% [markdown]
# ## Sequencial Processing

# %%
def calculate_od_paths(G: nx.Graph, 
                      origins = None, 
                      destinations = None, 
                      max_pairs= 1000):
    
    if origins is None or destinations is None:
        origins, destinations = identify_potential_origins_destinations(G)
    
    # Initialize containers
    path_dataset = []
    processed_pairs = set()
    invalid_pairs = set()
    
    # Create pairs of origins and destinations
    all_pairs = [(o, d) for o in origins for d in destinations if o != d]
    
    # Log initial statistics
    print(f"Total potential OD pairs: {len(all_pairs)}")
    
    # Process pairs
    for o, d in all_pairs:
        # if len(path_dataset) >= max_pairs:
        #     print(f"Reached maximum number of pairs ({max_pairs})")
        #     break
            
        if (o, d) in processed_pairs or (o, d) in invalid_pairs:
            continue
            
        print(f"\nProcessing path from {o} to {d}:")
        
        # Check basic path existence
        if not nx.has_path(G, o, d):
            print(f"No path exists between {o} and {d}")
            invalid_pairs.add((o, d))
            continue
        
        try:
            # Find shortest path
            path = nx.shortest_path(G, o, d, weight='weight')
            
            # Validate path edges
            skip_path = False
            edge_path = []
            total_weight = 0
            
            # Check each edge in the path
            for i in range(len(path)-1):
                u, v = path[i], path[i+1]
                edge_data = G[u][v]
                
                # Check for valid weight
                weight = edge_data.get('weight')
                if weight is None or np.isnan(weight):
                    print(f"Edge ({u}, {v}) has invalid weight: {weight}")
                    skip_path = True
                    invalid_pairs.add((o, d))
                    break
                
                # Collect edge information
                edge_info = {
                    'edge': (u, v),
                    'weight': weight,
                    'road_id': edge_data.get('road_id'),
                    'length': len(path) - 1
                }
                edge_path.append(edge_info)
                total_weight += weight
            
            if not skip_path:
                # Create path entry
                path_entry = {
                    'origin': o,
                    'destination': d,
                    'path': edge_path,
                    'total_weight': total_weight,
                    'path_length': len(path) - 1,
                    'node_path': path
                }
                
                path_dataset.append(path_entry)
                processed_pairs.add((o, d))
                print(f"Valid path found with {len(path)-1} edges and total weight {total_weight:.3f}")
                
        except nx.NetworkXNoPath:
            print(f"No valid path exists between {o} and {d}")
            invalid_pairs.add((o, d))
            continue
        except Exception as e:
            print(f"Error processing path {o} to {d}: {str(e)}")
            invalid_pairs.add((o, d))
            continue
    
    # Final statistics
    print("\nPath Calculation Summary:")
    print(f"Total valid paths found: {len(path_dataset)}")
    print(f"Total invalid pairs: {len(invalid_pairs)}")
    print(f"Total processed pairs: {len(processed_pairs)}")
    
    # Basic validation statistics
    if path_dataset:
        weights = [path['total_weight'] for path in path_dataset]
        lengths = [path['path_length'] for path in path_dataset]
        print("\nPath Statistics:")
        print(f"Average path length: {np.mean(lengths):.2f} edges")
        print(f"Average path weight: {np.mean(weights):.2f}")
        print(f"Weight range: {np.min(weights):.2f} to {np.max(weights):.2f}")
    
    return path_dataset

################################################################################################

def analyze_paths(path_dataset):
    """
    Analyze the calculated paths
    """
    if not path_dataset:
        return {"error": "No paths in dataset"}
    
    path_stats = {
        'total_paths': len(path_dataset),
        'avg_path_length': sum(path['path'][0]['length'] for path in path_dataset) / len(path_dataset),
        'min_path_length': min(path['path'][0]['length'] for path in path_dataset),
        'max_path_length': max(path['path'][0]['length'] for path in path_dataset),
        'avg_total_weight': sum(path['total_weight'] for path in path_dataset) / len(path_dataset),
        'min_total_weight': min(path['total_weight'] for path in path_dataset),
        'max_total_weight': max(path['total_weight'] for path in path_dataset)
    }
    
    return path_stats

def format_path_for_printing(path_info):
    """
    Formats a path for readable printing
    """
    output = [
        f"Origin: {path_info['origin']}",
        f"Destination: {path_info['destination']}",
        "Path:",
    ]
    
    for edge_info in path_info['path']:
        edge = edge_info['edge']
        weight = edge_info['weight']
        road_id = edge_info['road_id']
        output.append(f"  Edge{edge}(road_{road_id}): {weight:.3f}")
    
    output.append(f"Total Weight: {path_info['total_weight']:.3f}")
    output.append(f"Path Length: {path_info['path'][0]['length']} edges")
    
    return "\n".join(output)

# %% [markdown]
# ## Parallel Processing

# %%
def process_od_chunk(args):
    """
    Process a chunk of OD pairs in parallel.
    
    Parameters:
    -----------
    args : tuple
        (chunk_of_od_pairs, graph_data, chunk_id)
        
    Returns:
    --------
    list
        Valid paths found in this chunk
    """
    od_pairs, graph_data, chunk_id = args
    
    # Reconstruct graph from serialized data
    G = nx.Graph()
    G.add_edges_from(graph_data['edges'])
    nx.set_edge_attributes(G, graph_data['weights'], 'weight')
    nx.set_edge_attributes(G, graph_data['road_ids'], 'road_id')
    
    chunk_paths = []
    invalid_pairs = set()
    
    for o, d in od_pairs:
        try:
            if not nx.has_path(G, o, d):
                continue
                
            path = nx.shortest_path(G, o, d, weight='weight')
            
            # Validate path edges
            skip_path = False
            edge_path = []
            total_weight = 0
            
            for i in range(len(path)-1):
                u, v = path[i], path[i+1]
                edge_data = G[u][v]
                
                weight = edge_data.get('weight')
                if weight is None or np.isnan(weight):
                    skip_path = True
                    invalid_pairs.add((o, d))
                    break
                
                edge_info = {
                    'edge': (u, v),
                    'weight': weight,
                    'road_id': edge_data.get('road_id'),
                    'length': len(path) - 1
                }
                edge_path.append(edge_info)
                total_weight += weight
            
            if not skip_path:
                path_entry = {
                    'origin': o,
                    'destination': d,
                    'path': edge_path,
                    'total_weight': total_weight,
                    'path_length': len(path) - 1,
                    'node_path': path,
                    'chunk_id': chunk_id
                }
                chunk_paths.append(path_entry)
                
        except (nx.NetworkXNoPath, Exception):
            invalid_pairs.add((o, d))
            continue
    
    return chunk_paths
#---------------------------------------------------------------------------------------------------------------------
def save_chunk_to_disk(chunk_paths: List[Dict], chunk_id: int, output_dir: str):
    """Save chunk results to disk to free up memory"""
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    chunk_df = pd.DataFrame(chunk_paths)
    chunk_df.to_parquet(f"{output_dir}/chunk_{chunk_id}.parquet")

#---------------------------------------------------------------------------------------------------------------------------------------------
def calculate_od_paths_parallel(G: nx.Graph,
                              origins= None,
                              destinations = None,
                              max_pairs: int = None,
                              chunk_size: int = 10000,
                              n_cores: int = None,
                              output_dir: str = "od_path_chunks") -> List[Dict[str, Any]]:
    """
    Calculate shortest paths between OD pairs in parallel using chunking.
    
    Parameters:
    -----------
    G : networkx.Graph
        Network graph with edge weights
    origins : list, optional
        List of origin nodes
    destinations : list, optional
        List of destination nodes
    max_pairs : int, optional
        Maximum number of OD pairs to process
    chunk_size : int, default=10000
        Number of OD pairs to process in each chunk
    n_cores : int, optional
        Number of CPU cores to use
    output_dir : str, default="od_path_chunks"
        Directory to store chunk results
        
    Returns:
    --------
    list
        List of valid paths
    """
    # Set number of cores
    if n_cores is None:
        n_cores = min(10, cpu_count())  # Use max 16 cores or available cores
    
    print(f"Using {n_cores} CPU cores")
    
    # Create pairs of origins and destinations
    all_pairs = list(itertools.product(origins, destinations))
    all_pairs = [(o, d) for o, d in all_pairs if o != d]
    
    if max_pairs:
        all_pairs = all_pairs[:max_pairs]
    
    total_pairs = len(all_pairs)
    print(f"Total OD pairs to process: {total_pairs}")
    
    # Prepare graph data for serialization
    graph_data = {
        'edges': list(G.edges()),
        'weights': nx.get_edge_attributes(G, 'weight'),
        'road_ids': nx.get_edge_attributes(G, 'road_id')
    }
    
    # Create chunks
    chunks = []
    for i in range(0, len(all_pairs), chunk_size):
        chunk = all_pairs[i:i + chunk_size]
        chunks.append((chunk, graph_data, i//chunk_size))
    
    print(f"Created {len(chunks)} chunks of size {chunk_size}")
    
    # Process chunks in parallel
    start_time = time.time()
    path_dataset = []
    
    with Pool(n_cores) as pool:
        # Process chunks with progress bar
        for chunk_paths in tqdm(pool.imap_unordered(process_od_chunk, chunks),
                              total=len(chunks),
                              desc="Processing chunks"):
            # Save chunk results to disk
            if chunk_paths:
                save_chunk_to_disk(chunk_paths, len(path_dataset), output_dir)
                path_dataset.extend(chunk_paths)
    
    end_time = time.time()
    print(f"\nProcessing completed in {end_time - start_time:.2f} seconds")
    
    # Compile statistics
    print("\nPath Calculation Summary:")
    print(f"Total valid paths found: {len(path_dataset)}")
    print(f"Success rate: {len(path_dataset)/total_pairs*100:.2f}%")
    
    if path_dataset:
        weights = [path['total_weight'] for path in path_dataset]
        lengths = [path['path_length'] for path in path_dataset]
        print("\nPath Statistics:")
        print(f"Average path length: {np.mean(lengths):.2f} edges")
        print(f"Average path weight: {np.mean(weights):.2f}")
        print(f"Weight range: {np.min(weights):.2f} to {np.max(weights):.2f}")
    
    return path_dataset

#--------------------------------------------------------------------------------------------------------------
def combine_chunk_results(output_dir: str) -> pd.DataFrame:
    """
    Combine all chunk results into a single DataFrame
    """
    all_chunks = []
    for chunk_file in os.listdir(output_dir):
        if chunk_file.endswith('.parquet'):
            chunk_df = pd.read_parquet(os.path.join(output_dir, chunk_file))
            all_chunks.append(chunk_df)
    
    return pd.concat(all_chunks, ignore_index=True)

#example usage
'''
# Set parameters
chunk_size = 10000  # Adjust based on available memory
n_cores = 10  # Use 10 cores
output_chunk_dir = "od_path_results"

# Calculate paths in parallel
od_path_dataset = calculate_od_paths_parallel(
    G_workday_48,
    origins= source_hubs,
    destinations=destination_hubs,
    chunk_size=chunk_size,
    n_cores=n_cores,
    output_dir=output_chunk_dir
)
'''
# Out:
# '\n# Set parameters\nchunk_size = 10000  # Adjust based on available memory\nn_cores = 10  # Use 10 cores\noutput_chunk_dir = "od_path_results"\n\n# Calculate paths in parallel\nod_path_dataset = calculate_od_paths_parallel(\n    G_workday_48,\n    origins= source_hubs,\n    destinations=destination_hubs,\n    chunk_size=chunk_size,\n    n_cores=n_cores,\n    output_dir=output_chunk_dir\n)\n'

# %%
# Calculate paths using graph structure to identify OD pairs
# od_path_dataset = calculate_od_paths(G_workday_48)

# origins, destinations, degree_cent, betweenness_cent = identify_potential_origins_destinations(G)

# %%
# # Create pairs of origins and destinations
# all_pairs = [(o, d) for o in origins for d in destinations if o != d]

# # Log initial statistics
# print(f"Total potential OD pairs: {len(all_pairs)}")
# Out:
# Total potential OD pairs: 21804876

# %%
 # Analyze node degrees
in_degrees = dict(G.in_degree())
out_degrees = dict(G.out_degree())
k =500

# Find important nodes

# Nodes with highest in-degree (destination hubs)
high_in_degree = sorted(in_degrees.items(), key=lambda x: x[1], reverse=True)[:k]
destination_hubs =[int(node) for node, degree in high_in_degree]

# Nodes with highest out-degree (source hubs)
high_out_degree = sorted(out_degrees.items(), key=lambda x: x[1], reverse=True)[:k]
source_hubs = [int(node) for node, degree in high_out_degree]

# Create pairs of origins and destinations
all_pairs = [(o, d) for o in source_hubs for d in destination_hubs if o != d]

# Log initial statistics
print(f"Total potential OD pairs: {len(all_pairs)}")
# Out:
# Total potential OD pairs: 249833

# %%
# Set parameters
chunk_size = 10000  # Adjust based on available memory
n_cores = 10  # Use 10 cores
output_chunk_dir = "od_path_results"

# Calculate paths in parallel
od_path_dataset = calculate_od_paths_parallel(
    G_workday_48,
    origins= source_hubs,
    destinations=destination_hubs,
    chunk_size=chunk_size,
    n_cores=n_cores,
    output_dir=output_chunk_dir
)

# # Combine results if needed
# full_results_df = combine_chunk_results(output_chunk_dir)

# # Clean up temporary files if desired
# import shutil
# shutil.rmtree(output_chunk_dir)
# Out:
# Using 10 CPU cores
# Total OD pairs to process: 249833
# Created 25 chunks of size 10000
# Processing chunks:   0%|          | 0/25 [00:00<?, ?it/s]

# %%
# od_path_dataset = calculate_od_paths(G_workday_48, origins, destinations)

# # Analyze the paths
# stats = analyze_paths(od_path_dataset)
# print("\nPath Statistics:")
# for key, value in stats.items():
#     print(f"{key}: {value}")

# Print some example paths
# print("\nExample Paths:")
# for path_info in od_path_dataset[:5]:  # print first 5 paths
#     print("\n" + format_path_for_printing(path_info))
# Out:
# Total potential OD pairs: 22116719
#
# Processing path from 4845 to 54055:
# Edge (52041, 53536) has invalid weight: nan
#
# Processing path from 4845 to 56790:
# Edge (68661, 69440) has invalid weight: nan
#
# Processing path from 4845 to 67359:
# Edge (65991, 65989) has invalid weight: nan
#
# Processing path from 4845 to 10182:
# Valid path found with 81 edges and total weight 175.971
#
# Processing path from 4845 to 20060:
# Valid path found with 56 edges and total weight 106.817
#
# Processing path from 4845 to 4850:
# Valid path found with 9 edges and total weight 19.497
#
# Processing path from 4845 to 6117:
# Edge (2359, 745) has invalid weight: nan
#
# Processing path from 4845 to 20497:
# Valid path found with 219 edges and total weight 399.745
#
# Processing path from 4845 to 44603:
# Valid path found with 109 edges and total weight 207.271
#
# Processing path from 4845 to 7572:
# Edge (7175, 7180) has invalid weight: nan
#
# Processing path from 4845 to 40177:
# Valid path found with 206 edges and total weight 426.774
#
# Processing path from 4845 to 67852:
# Valid path found with 110 edges and total weight 220.927
#
# Processing path from 4845 to 7609:
# Valid path found with 105 edges and total weight 182.628
#
# Processing path from 4845 to 15595:
# Valid path found with 99 edges and total weight 208.815
#
# Processing path from 4845 to 53492:
# Edge (52041, 53536) has invalid weight: nan
#
# Processing path from 4845 to 44507:
# Valid path found with 324 edges and total weight 738.855
#
# Processing path from 4845 to 30068:
# Valid path found with 80 edges and total weight 150.476
#
# Processing path from 4845 to 42374:
# Edge (54245, 54243) has invalid weight: nan
#
# Processing path from 4845 to 32207:
# Valid path found with 88 edges and total weight 191.531
#
# Processing path from 4845 to 29281:
# Valid path found with 47 edges and total weight 82.981
#
# Processing path from 4845 to 4522:
# Valid path found with 50 edges and total weight 104.781
#
# Processing path from 4845 to 16124:
# Valid path found with 74 edges and total weight 169.191
#
# Processing path from 4845 to 35252:
# Edge (28443, 28764) has invalid weight: nan
#
# Processing path from 4845 to 10891:
# Valid path found with 56 edges and total weight 122.802
#
# Processing path from 4845 to 7566:
# Edge (7175, 7180) has invalid weight: nan
#
# Processing path from 4845 to 40814:
# Valid path found with 150 edges and total weight 271.760
#
# Processing path from 4845 to 69359:
# Valid path found with 161 edges and total weight 354.796
#
# Processing path from 4845 to 36577:
# Valid path found with 156 edges and total weight 320.536
#
# Processing path from 4845 to 35272:
# Valid path found with 44 edges and total weight 96.954
#
# Processing path from 4845 to 30544:
# Valid path found with 89 edges and total weight 202.831
#
# Processing path from 4845 to 30067:
# Valid path found with 79 edges and total weight 147.665
#
# Processing path from 4845 to 29968:
# Valid path found with 74 edges and total weight 128.718
#
# Processing path from 4845 to 64253:
# Valid path found with 119 edges and total weight 320.563
#
# Processing path from 4845 to 7303:
# Valid path found with 54 edges and total weight 112.626
#
# Processing path from 4845 to 41549:
# Valid path found with 255 edges and total weight 570.621
#
# Processing path from 4845 to 17465:
# Valid path found with 55 edges and total weight 107.957
#
# Processing path from 4845 to 7161:
# Valid path found with 31 edges and total weight 61.147
#
# Processing path from 4845 to 70320:
# Error processing path 4845 to 70320: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 67507:
# Edge (65664, 65665) has invalid weight: nan
#
# Processing path from 4845 to 4910:
# Valid path found with 8 edges and total weight 18.108
#
# Processing path from 4845 to 7619:
# Edge (8502, 8501) has invalid weight: nan
#
# Processing path from 4845 to 52343:
# Edge (52041, 53536) has invalid weight: nan
#
# Processing path from 4845 to 29486:
# Valid path found with 72 edges and total weight 138.529
#
# Processing path from 4845 to 45082:
# Valid path found with 130 edges and total weight 264.482
#
# Processing path from 4845 to 14013:
# Valid path found with 206 edges and total weight 466.779
#
# Processing path from 4845 to 17194:
# Valid path found with 54 edges and total weight 100.843
#
# Processing path from 4845 to 71363:
# Valid path found with 122 edges and total weight 263.941
#
# Processing path from 4845 to 43907:
# Valid path found with 128 edges and total weight 248.467
#
# Processing path from 4845 to 2752:
# Valid path found with 51 edges and total weight 109.312
#
# Processing path from 4845 to 4094:
# Valid path found with 33 edges and total weight 77.733
#
# Processing path from 4845 to 15198:
# Valid path found with 73 edges and total weight 148.143
#
# Processing path from 4845 to 29762:
# Valid path found with 126 edges and total weight 229.887
#
# Processing path from 4845 to 51287:
# Edge (41194, 41195) has invalid weight: nan
#
# Processing path from 4845 to 10724:
# Valid path found with 33 edges and total weight 64.954
#
# Processing path from 4845 to 26538:
# Edge (2359, 745) has invalid weight: nan
#
# Processing path from 4845 to 11315:
# Valid path found with 65 edges and total weight 119.040
#
# Processing path from 4845 to 3511:
# Edge (64747, 64748) has invalid weight: nan
#
# Processing path from 4845 to 15199:
# Valid path found with 56 edges and total weight 111.383
#
# Processing path from 4845 to 28449:
# Valid path found with 63 edges and total weight 122.500
#
# Processing path from 4845 to 43934:
# Valid path found with 179 edges and total weight 343.369
#
# Processing path from 4845 to 72249:
# Edge (30066, 30584) has invalid weight: nan
#
# Processing path from 4845 to 7274:
# Valid path found with 56 edges and total weight 120.619
#
# Processing path from 4845 to 35523:
# Valid path found with 52 edges and total weight 91.642
#
# Processing path from 4845 to 42925:
# Valid path found with 211 edges and total weight 436.170
#
# Processing path from 4845 to 54170:
# Edge (14885, 14583) has invalid weight: nan
#
# Processing path from 4845 to 16227:
# Valid path found with 65 edges and total weight 138.899
#
# Processing path from 4845 to 20036:
# Valid path found with 192 edges and total weight 397.020
#
# Processing path from 4845 to 5732:
# Valid path found with 60 edges and total weight 150.743
#
# Processing path from 4845 to 39407:
# Valid path found with 107 edges and total weight 210.469
#
# Processing path from 4845 to 43900:
# Error processing path 4845 to 43900: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 15235:
# Valid path found with 50 edges and total weight 95.665
#
# Processing path from 4845 to 30645:
# Valid path found with 74 edges and total weight 136.280
#
# Processing path from 4845 to 31196:
# Valid path found with 122 edges and total weight 234.931
#
# Processing path from 4845 to 15823:
# Valid path found with 135 edges and total weight 280.982
#
# Processing path from 4845 to 36073:
# Valid path found with 131 edges and total weight 272.463
#
# Processing path from 4845 to 35489:
# Valid path found with 93 edges and total weight 166.491
#
# Processing path from 4845 to 4040:
# Valid path found with 28 edges and total weight 65.139
#
# Processing path from 4845 to 3994:
# Valid path found with 22 edges and total weight 48.537
#
# Processing path from 4845 to 35054:
# Valid path found with 106 edges and total weight 243.216
#
# Processing path from 4845 to 30086:
# Valid path found with 113 edges and total weight 227.804
#
# Processing path from 4845 to 40642:
# Valid path found with 228 edges and total weight 457.201
#
# Processing path from 4845 to 10747:
# Valid path found with 47 edges and total weight 114.929
#
# Processing path from 4845 to 40896:
# Valid path found with 173 edges and total weight 344.222
#
# Processing path from 4845 to 23440:
# Edge (14885, 14583) has invalid weight: nan
#
# Processing path from 4845 to 53665:
# Valid path found with 125 edges and total weight 236.929
#
# Processing path from 4845 to 42821:
# Valid path found with 207 edges and total weight 425.337
#
# Processing path from 4845 to 37254:
# Valid path found with 127 edges and total weight 242.522
#
# Processing path from 4845 to 2827:
# Valid path found with 37 edges and total weight 70.030
#
# Processing path from 4845 to 45430:
# Valid path found with 160 edges and total weight 287.686
#
# Processing path from 4845 to 39426:
# Valid path found with 112 edges and total weight 223.531
#
# Processing path from 4845 to 21667:
# Valid path found with 122 edges and total weight 243.837
#
# Processing path from 4845 to 39400:
# Valid path found with 206 edges and total weight 430.181
#
# Processing path from 4845 to 54349:
# Valid path found with 116 edges and total weight 222.389
#
# Processing path from 4845 to 7440:
# Valid path found with 38 edges and total weight 77.490
#
# Processing path from 4845 to 22552:
# Valid path found with 105 edges and total weight 214.340
#
# Processing path from 4845 to 31494:
# Valid path found with 60 edges and total weight 109.752
#
# Processing path from 4845 to 32859:
# Valid path found with 70 edges and total weight 126.496
#
# Processing path from 4845 to 44438:
# Valid path found with 116 edges and total weight 222.811
#
# Processing path from 4845 to 46416:
# Edge (54207, 54208) has invalid weight: nan
#
# Processing path from 4845 to 35081:
# Valid path found with 99 edges and total weight 201.766
#
# Processing path from 4845 to 42124:
# Valid path found with 155 edges and total weight 319.042
#
# Processing path from 4845 to 35114:
# Valid path found with 113 edges and total weight 220.087
#
# Processing path from 4845 to 43905:
# Valid path found with 253 edges and total weight 510.531
#
# Processing path from 4845 to 41384:
# Valid path found with 142 edges and total weight 271.633
#
# Processing path from 4845 to 51331:
# Valid path found with 83 edges and total weight 158.941
#
# Processing path from 4845 to 7281:
# Valid path found with 64 edges and total weight 131.354
#
# Processing path from 4845 to 19093:
# Valid path found with 82 edges and total weight 162.773
#
# Processing path from 4845 to 12947:
# Valid path found with 153 edges and total weight 328.271
#
# Processing path from 4845 to 67412:
# Valid path found with 248 edges and total weight 574.542
#
# Processing path from 4845 to 11357:
# Valid path found with 65 edges and total weight 132.718
#
# Processing path from 4845 to 68728:
# Edge (72185, 72186) has invalid weight: nan
#
# Processing path from 4845 to 71050:
# Valid path found with 159 edges and total weight 441.953
#
# Processing path from 4845 to 29143:
# Valid path found with 51 edges and total weight 89.203
#
# Processing path from 4845 to 67349:
# Valid path found with 105 edges and total weight 233.362
#
# Processing path from 4845 to 38605:
# Valid path found with 108 edges and total weight 213.500
#
# Processing path from 4845 to 42456:
# Error processing path 4845 to 42456: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 36122:
# Valid path found with 236 edges and total weight 504.134
#
# Processing path from 4845 to 11030:
# Valid path found with 28 edges and total weight 69.611
#
# Processing path from 4845 to 29090:
# Valid path found with 40 edges and total weight 72.584
#
# Processing path from 4845 to 55335:
# Valid path found with 155 edges and total weight 373.398
#
# Processing path from 4845 to 12771:
# Valid path found with 114 edges and total weight 225.188
#
# Processing path from 4845 to 35061:
# Valid path found with 65 edges and total weight 149.721
#
# Processing path from 4845 to 70922:
# Edge (54247, 54248) has invalid weight: nan
#
# Processing path from 4845 to 41380:
# Valid path found with 144 edges and total weight 276.730
#
# Processing path from 4845 to 31816:
# Valid path found with 183 edges and total weight 375.631
#
# Processing path from 4845 to 35134:
# Valid path found with 75 edges and total weight 128.839
#
# Processing path from 4845 to 31191:
# Valid path found with 168 edges and total weight 340.002
#
# Processing path from 4845 to 36213:
# Valid path found with 87 edges and total weight 168.754
#
# Processing path from 4845 to 43354:
# Valid path found with 151 edges and total weight 275.138
#
# Processing path from 4845 to 41990:
# Valid path found with 167 edges and total weight 297.369
#
# Processing path from 4845 to 9944:
# Valid path found with 39 edges and total weight 93.355
#
# Processing path from 4845 to 3922:
# Valid path found with 41 edges and total weight 77.543
#
# Processing path from 4845 to 20562:
# Valid path found with 95 edges and total weight 199.199
#
# Processing path from 4845 to 56791:
# Edge (68661, 69440) has invalid weight: nan
#
# Processing path from 4845 to 11345:
# Valid path found with 44 edges and total weight 89.460
#
# Processing path from 4845 to 67552:
# Valid path found with 67 edges and total weight 134.656
#
# Processing path from 4845 to 29000:
# Valid path found with 48 edges and total weight 85.157
#
# Processing path from 4845 to 11214:
# Valid path found with 59 edges and total weight 113.209
#
# Processing path from 4845 to 15210:
# Valid path found with 82 edges and total weight 184.410
#
# Processing path from 4845 to 8133:
# Valid path found with 61 edges and total weight 127.862
#
# Processing path from 4845 to 19290:
# Valid path found with 43 edges and total weight 92.923
#
# Processing path from 4845 to 20642:
# Valid path found with 92 edges and total weight 189.110
#
# Processing path from 4845 to 21762:
# Valid path found with 126 edges and total weight 249.518
#
# Processing path from 4845 to 51468:
# Valid path found with 245 edges and total weight 472.121
#
# Processing path from 4845 to 7482:
# Valid path found with 62 edges and total weight 128.068
#
# Processing path from 4845 to 12930:
# Valid path found with 133 edges and total weight 267.197
#
# Processing path from 4845 to 11007:
# Edge (8502, 8501) has invalid weight: nan
#
# Processing path from 4845 to 20699:
# Edge (14885, 14583) has invalid weight: nan
#
# Processing path from 4845 to 38912:
# Valid path found with 172 edges and total weight 338.613
#
# Processing path from 4845 to 22948:
# Valid path found with 80 edges and total weight 170.034
#
# Processing path from 4845 to 11246:
# Valid path found with 48 edges and total weight 98.412
#
# Processing path from 4845 to 30088:
# Valid path found with 114 edges and total weight 230.667
#
# Processing path from 4845 to 24942:
# Valid path found with 176 edges and total weight 406.647
#
# Processing path from 4845 to 7194:
# Valid path found with 64 edges and total weight 143.347
#
# Processing path from 4845 to 70975:
# Valid path found with 149 edges and total weight 335.617
#
# Processing path from 4845 to 31784:
# Edge (11945, 8493) has invalid weight: nan
#
# Processing path from 4845 to 40834:
# Edge (14885, 14583) has invalid weight: nan
#
# Processing path from 4845 to 35154:
# Valid path found with 91 edges and total weight 163.267
#
# Processing path from 4845 to 73803:
# Edge (30066, 30584) has invalid weight: nan
#
# Processing path from 4845 to 21571:
# Valid path found with 112 edges and total weight 218.693
#
# Processing path from 4845 to 6216:
# Valid path found with 78 edges and total weight 149.916
#
# Processing path from 4845 to 7342:
# Valid path found with 53 edges and total weight 114.510
#
# Processing path from 4845 to 4998:
# Valid path found with 46 edges and total weight 100.307
#
# Processing path from 4845 to 42520:
# Valid path found with 123 edges and total weight 223.092
#
# Processing path from 4845 to 57294:
# Edge (68661, 69440) has invalid weight: nan
#
# Processing path from 4845 to 8900:
# Valid path found with 102 edges and total weight 174.794
#
# Processing path from 4845 to 72179:
# Valid path found with 270 edges and total weight 636.715
#
# Processing path from 4845 to 32556:
# Valid path found with 87 edges and total weight 148.904
#
# Processing path from 4845 to 72252:
# Valid path found with 273 edges and total weight 647.316
#
# Processing path from 4845 to 11229:
# Valid path found with 51 edges and total weight 108.702
#
# Processing path from 4845 to 7028:
# Valid path found with 61 edges and total weight 128.885
#
# Processing path from 4845 to 19303:
# Valid path found with 34 edges and total weight 71.613
#
# Processing path from 4845 to 72456:
# Edge (54389, 54391) has invalid weight: nan
#
# Processing path from 4845 to 15842:
# Valid path found with 81 edges and total weight 157.092
#
# Processing path from 4845 to 29534:
# Valid path found with 54 edges and total weight 98.848
#
# Processing path from 4845 to 67865:
# Edge (67508, 67507) has invalid weight: nan
#
# Processing path from 4845 to 20577:
# Valid path found with 99 edges and total weight 197.368
#
# Processing path from 4845 to 31735:
# Valid path found with 101 edges and total weight 184.483
#
# Processing path from 4845 to 31087:
# Valid path found with 178 edges and total weight 366.369
#
# Processing path from 4845 to 40220:
# Edge (51326, 51785) has invalid weight: nan
#
# Processing path from 4845 to 3333:
# Valid path found with 22 edges and total weight 43.082
#
# Processing path from 4845 to 15867:
# Valid path found with 107 edges and total weight 214.888
#
# Processing path from 4845 to 29886:
# Valid path found with 69 edges and total weight 139.377
#
# Processing path from 4845 to 35447:
# Valid path found with 48 edges and total weight 84.593
#
# Processing path from 4845 to 39635:
# Valid path found with 204 edges and total weight 426.222
#
# Processing path from 4845 to 2828:
# Valid path found with 38 edges and total weight 71.875
#
# Processing path from 4845 to 5712:
# Valid path found with 48 edges and total weight 105.714
#
# Processing path from 4845 to 16742:
# Valid path found with 72 edges and total weight 145.241
#
# Processing path from 4845 to 18122:
# Valid path found with 68 edges and total weight 130.480
#
# Processing path from 4845 to 53951:
# Edge (54247, 54248) has invalid weight: nan
#
# Processing path from 4845 to 36740:
# Valid path found with 178 edges and total weight 316.518
#
# Processing path from 4845 to 9029:
# Valid path found with 80 edges and total weight 173.661
#
# Processing path from 4845 to 35046:
# Valid path found with 120 edges and total weight 253.639
#
# Processing path from 4845 to 28374:
# Valid path found with 59 edges and total weight 123.020
#
# Processing path from 4845 to 2785:
# Valid path found with 46 edges and total weight 94.782
#
# Processing path from 4845 to 31557:
# Valid path found with 70 edges and total weight 120.822
#
# Processing path from 4845 to 45423:
# Valid path found with 130 edges and total weight 255.985
#
# Processing path from 4845 to 16511:
# Valid path found with 73 edges and total weight 153.313
#
# Processing path from 4845 to 17701:
# Valid path found with 64 edges and total weight 138.332
#
# Processing path from 4845 to 71478:
# Edge (14885, 14583) has invalid weight: nan
#
# Processing path from 4845 to 15487:
# Valid path found with 96 edges and total weight 198.130
#
# Processing path from 4845 to 67855:
# Edge (67508, 67507) has invalid weight: nan
#
# Processing path from 4845 to 11236:
# Valid path found with 69 edges and total weight 127.036
#
# Processing path from 4845 to 12429:
# Valid path found with 111 edges and total weight 244.954
#
# Processing path from 4845 to 16618:
# Valid path found with 78 edges and total weight 169.632
#
# Processing path from 4845 to 11322:
# Valid path found with 114 edges and total weight 247.774
#
# Processing path from 4845 to 35162:
# Valid path found with 79 edges and total weight 140.011
#
# Processing path from 4845 to 67683:
# Valid path found with 129 edges and total weight 338.369
#
# Processing path from 4845 to 69544:
# Valid path found with 205 edges and total weight 482.649
#
# Processing path from 4845 to 15547:
# Edge (14885, 14583) has invalid weight: nan
#
# Processing path from 4845 to 35517:
# Valid path found with 94 edges and total weight 172.312
#
# Processing path from 4845 to 16139:
# Valid path found with 96 edges and total weight 192.394
#
# Processing path from 4845 to 21461:
# Valid path found with 104 edges and total weight 209.239
#
# Processing path from 4845 to 6867:
# Valid path found with 63 edges and total weight 135.068
#
# Processing path from 4845 to 17112:
# Valid path found with 86 edges and total weight 188.993
#
# Processing path from 4845 to 12273:
# Error processing path 4845 to 12273: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 36703:
# Valid path found with 132 edges and total weight 256.142
#
# Processing path from 4845 to 68383:
# Error processing path 4845 to 68383: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 38765:
# Edge (38840, 38833) has invalid weight: nan
#
# Processing path from 4845 to 51251:
# Edge (41194, 41195) has invalid weight: nan
#
# Processing path from 4845 to 35552:
# Edge (2359, 745) has invalid weight: nan
#
# Processing path from 4845 to 72250:
# Valid path found with 272 edges and total weight 643.640
#
# Processing path from 4845 to 32647:
# Valid path found with 91 edges and total weight 161.128
#
# Processing path from 4845 to 39442:
# Valid path found with 114 edges and total weight 230.754
#
# Processing path from 4845 to 14146:
# Valid path found with 132 edges and total weight 245.508
#
# Processing path from 4845 to 35621:
# Valid path found with 112 edges and total weight 219.678
#
# Processing path from 4845 to 55083:
# Edge (54187, 54188) has invalid weight: nan
#
# Processing path from 4845 to 22410:
# Valid path found with 102 edges and total weight 202.552
#
# Processing path from 4845 to 57298:
# Edge (54389, 54391) has invalid weight: nan
#
# Processing path from 4845 to 29730:
# Valid path found with 88 edges and total weight 178.942
#
# Processing path from 4845 to 15078:
# Valid path found with 73 edges and total weight 166.523
#
# Processing path from 4845 to 14119:
# Valid path found with 134 edges and total weight 272.614
#
# Processing path from 4845 to 16601:
# Valid path found with 65 edges and total weight 144.375
#
# Processing path from 4845 to 65815:
# Error processing path 4845 to 65815: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 44743:
# Valid path found with 156 edges and total weight 345.825
#
# Processing path from 4845 to 37388:
# Valid path found with 155 edges and total weight 304.327
#
# Processing path from 4845 to 6887:
# Valid path found with 59 edges and total weight 110.160
#
# Processing path from 4845 to 12221:
# Error processing path 4845 to 12221: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 41383:
# Valid path found with 196 edges and total weight 406.680
#
# Processing path from 4845 to 11065:
# Valid path found with 61 edges and total weight 131.971
#
# Processing path from 4845 to 44525:
# Error processing path 4845 to 44525: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 53471:
# Edge (52041, 53536) has invalid weight: nan
#
# Processing path from 4845 to 67595:
# Edge (14885, 14583) has invalid weight: nan
#
# Processing path from 4845 to 5274:
# Valid path found with 12 edges and total weight 26.398
#
# Processing path from 4845 to 11094:
# Valid path found with 47 edges and total weight 97.584
#
# Processing path from 4845 to 67455:
# Valid path found with 105 edges and total weight 210.615
#
# Processing path from 4845 to 6116:
# Edge (65991, 65989) has invalid weight: nan
#
# Processing path from 4845 to 35059:
# Valid path found with 67 edges and total weight 155.319
#
# Processing path from 4845 to 31224:
# Valid path found with 144 edges and total weight 276.347
#
# Processing path from 4845 to 45535:
# Edge (38840, 38833) has invalid weight: nan
#
# Processing path from 4845 to 19038:
# Valid path found with 58 edges and total weight 116.333
#
# Processing path from 4845 to 67460:
# Valid path found with 110 edges and total weight 224.285
#
# Processing path from 4845 to 10591:
# Valid path found with 52 edges and total weight 113.094
#
# Processing path from 4845 to 17183:
# Valid path found with 67 edges and total weight 143.360
#
# Processing path from 4845 to 64732:
# Valid path found with 76 edges and total weight 149.434
#
# Processing path from 4845 to 14747:
# Error processing path 4845 to 14747: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 66438:
# Valid path found with 175 edges and total weight 411.928
#
# Processing path from 4845 to 15385:
# Valid path found with 76 edges and total weight 165.359
#
# Processing path from 4845 to 53405:
# Valid path found with 152 edges and total weight 307.799
#
# Processing path from 4845 to 16286:
# Valid path found with 78 edges and total weight 159.666
#
# Processing path from 4845 to 45058:
# Edge (54247, 54248) has invalid weight: nan
#
# Processing path from 4845 to 16491:
# Valid path found with 90 edges and total weight 199.310
#
# Processing path from 4845 to 30239:
# Valid path found with 70 edges and total weight 123.455
#
# Processing path from 4845 to 40967:
# Valid path found with 292 edges and total weight 636.156
#
# Processing path from 4845 to 34884:
# Valid path found with 119 edges and total weight 229.668
#
# Processing path from 4845 to 67510:
# Edge (64757, 67525) has invalid weight: nan
#
# Processing path from 4845 to 10645:
# Valid path found with 87 edges and total weight 199.340
#
# Processing path from 4845 to 14801:
# Error processing path 4845 to 14801: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 4922:
# Valid path found with 17 edges and total weight 32.854
#
# Processing path from 4845 to 10059:
# Valid path found with 60 edges and total weight 127.033
#
# Processing path from 4845 to 16697:
# Valid path found with 85 edges and total weight 183.611
#
# Processing path from 4845 to 11323:
# Valid path found with 115 edges and total weight 249.324
#
# Processing path from 4845 to 24880:
# Edge (23715, 23716) has invalid weight: nan
#
# Processing path from 4845 to 44829:
# Valid path found with 126 edges and total weight 255.385
#
# Processing path from 4845 to 14015:
# Valid path found with 225 edges and total weight 421.908
#
# Processing path from 4845 to 31210:
# Edge (2359, 745) has invalid weight: nan
#
# Processing path from 4845 to 7229:
# Edge (8502, 8501) has invalid weight: nan
#
# Processing path from 4845 to 48222:
# Edge (54207, 54208) has invalid weight: nan
#
# Processing path from 4845 to 36066:
# Valid path found with 117 edges and total weight 238.785
#
# Processing path from 4845 to 40721:
# Valid path found with 143 edges and total weight 275.078
#
# Processing path from 4845 to 2658:
# Valid path found with 54 edges and total weight 117.118
#
# Processing path from 4845 to 45458:
# Valid path found with 92 edges and total weight 166.925
#
# Processing path from 4845 to 29945:
# Error processing path 4845 to 29945: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 67415:
# Valid path found with 240 edges and total weight 552.601
#
# Processing path from 4845 to 29050:
# Valid path found with 50 edges and total weight 130.876
#
# Processing path from 4845 to 29967:
# Valid path found with 73 edges and total weight 126.780
#
# Processing path from 4845 to 32645:
# Valid path found with 131 edges and total weight 256.341
#
# Processing path from 4845 to 11096:
# Valid path found with 49 edges and total weight 102.133
#
# Processing path from 4845 to 29844:
# Valid path found with 67 edges and total weight 116.354
#
# Processing path from 4845 to 45028:
# Valid path found with 129 edges and total weight 248.302
#
# Processing path from 4845 to 10760:
# Valid path found with 97 edges and total weight 223.348
#
# Processing path from 4845 to 43550:
# Error processing path 4845 to 43550: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 16839:
# Edge (64745, 64908) has invalid weight: nan
#
# Processing path from 4845 to 14740:
# Edge (14885, 14583) has invalid weight: nan
#
# Processing path from 4845 to 14169:
# Valid path found with 113 edges and total weight 215.849
#
# Processing path from 4845 to 11278:
# Valid path found with 53 edges and total weight 112.080
#
# Processing path from 4845 to 29785:
# Valid path found with 119 edges and total weight 250.728
#
# Processing path from 4845 to 46626:
# Error processing path 4845 to 46626: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 6482:
# Edge (8502, 8501) has invalid weight: nan
#
# Processing path from 4845 to 24085:
# Valid path found with 155 edges and total weight 385.719
#
# Processing path from 4845 to 53708:
# Valid path found with 101 edges and total weight 188.322
#
# Processing path from 4845 to 4896:
# Valid path found with 24 edges and total weight 58.054
#
# Processing path from 4845 to 32425:
# Valid path found with 112 edges and total weight 233.742
#
# Processing path from 4845 to 7266:
# Valid path found with 48 edges and total weight 97.854
#
# Processing path from 4845 to 35069:
# Valid path found with 69 edges and total weight 160.096
#
# Processing path from 4845 to 15086:
# Valid path found with 100 edges and total weight 226.841
#
# Processing path from 4845 to 44844:
# Valid path found with 104 edges and total weight 192.737
#
# Processing path from 4845 to 40355:
# Error processing path 4845 to 40355: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 40263:
# Valid path found with 201 edges and total weight 412.792
#
# Processing path from 4845 to 26489:
# Edge (2359, 745) has invalid weight: nan
#
# Processing path from 4845 to 32148:
# Valid path found with 87 edges and total weight 158.173
#
# Processing path from 4845 to 17096:
# Valid path found with 75 edges and total weight 159.856
#
# Processing path from 4845 to 19024:
# Valid path found with 51 edges and total weight 99.308
#
# Processing path from 4845 to 17076:
# Valid path found with 115 edges and total weight 249.887
#
# Processing path from 4845 to 33186:
# Valid path found with 55 edges and total weight 95.279
#
# Processing path from 4845 to 56419:
# Edge (54207, 54208) has invalid weight: nan
#
# Processing path from 4845 to 38500:
# Valid path found with 93 edges and total weight 172.678
#
# Processing path from 4845 to 8749:
# Valid path found with 47 edges and total weight 94.866
#
# Processing path from 4845 to 38170:
# Valid path found with 152 edges and total weight 299.124
#
# Processing path from 4845 to 15192:
# Valid path found with 83 edges and total weight 189.542
#
# Processing path from 4845 to 20969:
# Valid path found with 105 edges and total weight 201.947
#
# Processing path from 4845 to 8704:
# Valid path found with 73 edges and total weight 157.411
#
# Processing path from 4845 to 72095:
# Valid path found with 146 edges and total weight 338.191
#
# Processing path from 4845 to 64713:
# Valid path found with 149 edges and total weight 343.451
#
# Processing path from 4845 to 44268:
# Valid path found with 106 edges and total weight 197.277
#
# Processing path from 4845 to 70915:
# Edge (14885, 14583) has invalid weight: nan
#
# Processing path from 4845 to 10984:
# Edge (11945, 8493) has invalid weight: nan
#
# Processing path from 4845 to 2570:
# Valid path found with 59 edges and total weight 124.048
#
# Processing path from 4845 to 35109:
# Valid path found with 105 edges and total weight 204.324
#
# Processing path from 4845 to 2693:
# Valid path found with 54 edges and total weight 115.685
#
# Processing path from 4845 to 18089:
# Valid path found with 75 edges and total weight 138.880
#
# Processing path from 4845 to 17347:
# Valid path found with 62 edges and total weight 132.543
#
# Processing path from 4845 to 35514:
# Valid path found with 114 edges and total weight 234.862
#
# Processing path from 4845 to 38574:
# Valid path found with 230 edges and total weight 487.673
#
# Processing path from 4845 to 18133:
# Valid path found with 70 edges and total weight 132.817
#
# Processing path from 4845 to 2403:
# Valid path found with 36 edges and total weight 74.339
#
# Processing path from 4845 to 54182:
# Edge (52041, 53536) has invalid weight: nan
#
# Processing path from 4845 to 64786:
# Edge (64757, 67525) has invalid weight: nan
#
# Processing path from 4845 to 73145:
# Edge (30066, 30584) has invalid weight: nan
#
# Processing path from 4845 to 53482:
# Valid path found with 114 edges and total weight 218.734
#
# Processing path from 4845 to 61570:
# Valid path found with 115 edges and total weight 282.754
#
# Processing path from 4845 to 38130:
# Valid path found with 154 edges and total weight 314.699
#
# Processing path from 4845 to 32724:
# Edge (2359, 745) has invalid weight: nan
#
# Processing path from 4845 to 6476:
# Valid path found with 66 edges and total weight 141.906
#
# Processing path from 4845 to 15951:
# Edge (14885, 14583) has invalid weight: nan
#
# Processing path from 4845 to 42001:
# Edge (54245, 54243) has invalid weight: nan
#
# Processing path from 4845 to 31441:
# Valid path found with 63 edges and total weight 108.754
#
# Processing path from 4845 to 22440:
# Valid path found with 213 edges and total weight 511.925
#
# Processing path from 4845 to 54856:
# Valid path found with 154 edges and total weight 371.637
#
# Processing path from 4845 to 518:
# Edge (2359, 745) has invalid weight: nan
#
# Processing path from 4845 to 66469:
# Valid path found with 238 edges and total weight 546.123
#
# Processing path from 4845 to 53431:
# Valid path found with 102 edges and total weight 220.029
#
# Processing path from 4845 to 15418:
# Valid path found with 129 edges and total weight 269.302
#
# Processing path from 4845 to 20563:
# Valid path found with 94 edges and total weight 192.845
#
# Processing path from 4845 to 8687:
# Valid path found with 78 edges and total weight 168.478
#
# Processing path from 4845 to 38767:
# Edge (38840, 38833) has invalid weight: nan
#
# Processing path from 4845 to 43469:
# Valid path found with 201 edges and total weight 420.381
#
# Processing path from 4845 to 42092:
# Valid path found with 177 edges and total weight 339.474
#
# Processing path from 4845 to 40284:
# Valid path found with 160 edges and total weight 318.203
#
# Processing path from 4845 to 11998:
# Valid path found with 91 edges and total weight 207.948
#
# Processing path from 4845 to 12092:
# Edge (65991, 65989) has invalid weight: nan
#
# Processing path from 4845 to 39775:
# Valid path found with 113 edges and total weight 227.801
#
# Processing path from 4845 to 35468:
# Valid path found with 82 edges and total weight 140.571
#
# Processing path from 4845 to 64830:
# Valid path found with 148 edges and total weight 333.303
#
# Processing path from 4845 to 39789:
# Valid path found with 79 edges and total weight 179.102
#
# Processing path from 4845 to 8028:
# Valid path found with 55 edges and total weight 118.273
#
# Processing path from 4845 to 44432:
# Valid path found with 121 edges and total weight 231.971
#
# Processing path from 4845 to 69469:
# Edge (14885, 14583) has invalid weight: nan
#
# Processing path from 4845 to 45473:
# Edge (45609, 54032) has invalid weight: nan
#
# Processing path from 4845 to 6203:
# Edge (65991, 65989) has invalid weight: nan
#
# Processing path from 4845 to 4582:
# Valid path found with 46 edges and total weight 96.427
#
# Processing path from 4845 to 65059:
# Edge (68661, 68659) has invalid weight: nan
#
# Processing path from 4845 to 2622:
# Edge (64747, 64748) has invalid weight: nan
#
# Processing path from 4845 to 42611:
# Valid path found with 203 edges and total weight 405.048
#
# Processing path from 4845 to 67439:
# Error processing path 4845 to 67439: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 11319:
# Edge (2359, 745) has invalid weight: nan
#
# Processing path from 4845 to 31226:
# Error processing path 4845 to 31226: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 41381:
# Valid path found with 143 edges and total weight 274.393
#
# Processing path from 4845 to 10735:
# Valid path found with 42 edges and total weight 109.321
#
# Processing path from 4845 to 18203:
# Valid path found with 78 edges and total weight 155.446
#
# Processing path from 4845 to 21596:
# Valid path found with 121 edges and total weight 238.823
#
# Processing path from 4845 to 19716:
# Error processing path 4845 to 19716: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 44504:
# Edge (68661, 69440) has invalid weight: nan
#
# Processing path from 4845 to 66001:
# Valid path found with 128 edges and total weight 307.312
#
# Processing path from 4845 to 15352:
# Valid path found with 88 edges and total weight 200.942
#
# Processing path from 4845 to 35097:
# Edge (45609, 54032) has invalid weight: nan
#
# Processing path from 4845 to 13152:
# Valid path found with 114 edges and total weight 217.422
#
# Processing path from 4845 to 14977:
# Valid path found with 71 edges and total weight 161.148
#
# Processing path from 4845 to 28402:
# Valid path found with 100 edges and total weight 210.716
#
# Processing path from 4845 to 11659:
# Valid path found with 63 edges and total weight 134.915
#
# Processing path from 4845 to 64706:
# Edge (65991, 65989) has invalid weight: nan
#
# Processing path from 4845 to 44477:
# Valid path found with 113 edges and total weight 215.544
#
# Processing path from 4845 to 44458:
# Valid path found with 107 edges and total weight 198.626
#
# Processing path from 4845 to 71058:
# Error processing path 4845 to 71058: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 2502:
# Valid path found with 48 edges and total weight 103.353
#
# Processing path from 4845 to 3395:
# Valid path found with 65 edges and total weight 129.290
#
# Processing path from 4845 to 2671:
# Valid path found with 46 edges and total weight 100.141
#
# Processing path from 4845 to 6889:
# Valid path found with 52 edges and total weight 98.021
#
# Processing path from 4845 to 4466:
# Valid path found with 66 edges and total weight 122.723
#
# Processing path from 4845 to 8057:
# Valid path found with 51 edges and total weight 102.834
#
# Processing path from 4845 to 22422:
# Valid path found with 149 edges and total weight 320.812
#
# Processing path from 4845 to 28235:
# Valid path found with 32 edges and total weight 59.623
#
# Processing path from 4845 to 67823:
# Edge (64757, 67525) has invalid weight: nan
#
# Processing path from 4845 to 46552:
# Edge (68661, 69440) has invalid weight: nan
#
# Processing path from 4845 to 22539:
# Valid path found with 100 edges and total weight 192.815
#
# Processing path from 4845 to 42074:
# Valid path found with 174 edges and total weight 343.881
#
# Processing path from 4845 to 21349:
# Valid path found with 128 edges and total weight 288.477
#
# Processing path from 4845 to 2513:
# Valid path found with 48 edges and total weight 103.235
#
# Processing path from 4845 to 22457:
# Valid path found with 111 edges and total weight 232.019
#
# Processing path from 4845 to 11348:
# Valid path found with 56 edges and total weight 114.762
#
# Processing path from 4845 to 17155:
# Valid path found with 91 edges and total weight 201.761
#
# Processing path from 4845 to 35136:
# Valid path found with 88 edges and total weight 160.069
#
# Processing path from 4845 to 51413:
# Valid path found with 121 edges and total weight 235.557
#
# Processing path from 4845 to 35491:
# Valid path found with 124 edges and total weight 226.526
#
# Processing path from 4845 to 42592:
# Valid path found with 154 edges and total weight 313.056
#
# Processing path from 4845 to 20627:
# Valid path found with 90 edges and total weight 183.786
#
# Processing path from 4845 to 67854:
# Edge (67508, 67507) has invalid weight: nan
#
# Processing path from 4845 to 39834:
# Error processing path 4845 to 39834: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 14179:
# Edge (14885, 14583) has invalid weight: nan
#
# Processing path from 4845 to 51329:
# Edge (52041, 53536) has invalid weight: nan
#
# Processing path from 4845 to 63849:
# Valid path found with 97 edges and total weight 184.052
#
# Processing path from 4845 to 15877:
# Valid path found with 99 edges and total weight 203.529
#
# Processing path from 4845 to 28403:
# Valid path found with 101 edges and total weight 233.238
#
# Processing path from 4845 to 26504:
# Edge (2359, 745) has invalid weight: nan
#
# Processing path from 4845 to 7413:
# Valid path found with 67 edges and total weight 136.388
#
# Processing path from 4845 to 17735:
# Valid path found with 60 edges and total weight 116.751
#
# Processing path from 4845 to 15488:
# Valid path found with 97 edges and total weight 223.062
#
# Processing path from 4845 to 7153:
# Valid path found with 34 edges and total weight 67.659
#
# Processing path from 4845 to 35394:
# Valid path found with 117 edges and total weight 215.018
#
# Processing path from 4845 to 4831:
# Valid path found with 6 edges and total weight 13.419
#
# Processing path from 4845 to 20245:
# Valid path found with 80 edges and total weight 161.689
#
# Processing path from 4845 to 20913:
# Valid path found with 115 edges and total weight 231.948
#
# Processing path from 4845 to 42121:
# Valid path found with 144 edges and total weight 284.959
#
# Processing path from 4845 to 11006:
# Valid path found with 104 edges and total weight 180.075
#
# Processing path from 4845 to 11227:
# Valid path found with 56 edges and total weight 116.867
#
# Processing path from 4845 to 19890:
# Valid path found with 61 edges and total weight 119.663
#
# Processing path from 4845 to 35082:
# Valid path found with 106 edges and total weight 220.364
#
# Processing path from 4845 to 13263:
# Valid path found with 149 edges and total weight 318.627
#
# Processing path from 4845 to 28432:
# Valid path found with 46 edges and total weight 102.466
#
# Processing path from 4845 to 20613:
# Valid path found with 107 edges and total weight 212.095
#
# Processing path from 4845 to 18436:
# Error processing path 4845 to 18436: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 44377:
# Valid path found with 107 edges and total weight 199.267
#
# Processing path from 4845 to 70988:
# Error processing path 4845 to 70988: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 55667:
# Valid path found with 130 edges and total weight 290.937
#
# Processing path from 4845 to 10566:
# Valid path found with 106 edges and total weight 241.683
#
# Processing path from 4845 to 22287:
# Error processing path 4845 to 22287: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 11167:
# Valid path found with 79 edges and total weight 175.044
#
# Processing path from 4845 to 4180:
# Valid path found with 30 edges and total weight 69.889
#
# Processing path from 4845 to 44280:
# Valid path found with 115 edges and total weight 213.117
#
# Processing path from 4845 to 15401:
# Valid path found with 81 edges and total weight 157.227
#
# Processing path from 4845 to 7570:
# Valid path found with 45 edges and total weight 94.135
#
# Processing path from 4845 to 5313:
# Valid path found with 23 edges and total weight 43.832
#
# Processing path from 4845 to 29904:
# Valid path found with 68 edges and total weight 117.682
#
# Processing path from 4845 to 32782:
# Edge (2359, 745) has invalid weight: nan
#
# Processing path from 4845 to 39838:
# Valid path found with 215 edges and total weight 465.650
#
# Processing path from 4845 to 7632:
# Valid path found with 66 edges and total weight 135.156
#
# Processing path from 4845 to 11049:
# Valid path found with 94 edges and total weight 159.679
#
# Processing path from 4845 to 4328:
# Valid path found with 54 edges and total weight 118.348
#
# Processing path from 4845 to 2643:
# Valid path found with 39 edges and total weight 84.278
#
# Processing path from 4845 to 15496:
# Valid path found with 102 edges and total weight 218.435
#
# Processing path from 4845 to 64583:
# Edge (7175, 7180) has invalid weight: nan
#
# Processing path from 4845 to 10481:
# Edge (11945, 8493) has invalid weight: nan
#
# Processing path from 4845 to 22537:
# Error processing path 4845 to 22537: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 67108:
# Error processing path 4845 to 67108: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 11958:
# Valid path found with 54 edges and total weight 131.830
#
# Processing path from 4845 to 17193:
# Valid path found with 77 edges and total weight 164.470
#
# Processing path from 4845 to 48279:
# Edge (54389, 54391) has invalid weight: nan
#
# Processing path from 4845 to 3393:
# Valid path found with 85 edges and total weight 183.990
#
# Processing path from 4845 to 15814:
# Valid path found with 97 edges and total weight 204.059
#
# Processing path from 4845 to 14569:
# Edge (68661, 69440) has invalid weight: nan
#
# Processing path from 4845 to 17627:
# Valid path found with 50 edges and total weight 108.204
#
# Processing path from 4845 to 15025:
# Valid path found with 81 edges and total weight 188.007
#
# Processing path from 4845 to 15899:
# Valid path found with 95 edges and total weight 194.736
#
# Processing path from 4845 to 29247:
# Valid path found with 62 edges and total weight 140.507
#
# Processing path from 4845 to 67808:
# Valid path found with 126 edges and total weight 266.790
#
# Processing path from 4845 to 32734:
# Valid path found with 71 edges and total weight 125.597
#
# Processing path from 4845 to 3037:
# Valid path found with 58 edges and total weight 128.333
#
# Processing path from 4845 to 73159:
# Edge (14885, 14583) has invalid weight: nan
#
# Processing path from 4845 to 53409:
# Error processing path 4845 to 53409: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 9146:
# Valid path found with 87 edges and total weight 199.727
#
# Processing path from 4845 to 35522:
# Valid path found with 56 edges and total weight 98.084
#
# Processing path from 4845 to 43930:
# Error processing path 4845 to 43930: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 53474:
# Edge (52041, 53536) has invalid weight: nan
#
# Processing path from 4845 to 73286:
# Valid path found with 349 edges and total weight 780.114
#
# Processing path from 4845 to 24093:
# Valid path found with 173 edges and total weight 398.290
#
# Processing path from 4845 to 71269:
# Valid path found with 97 edges and total weight 221.206
#
# Processing path from 4845 to 69258:
# Error processing path 4845 to 69258: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 20244:
# Valid path found with 77 edges and total weight 153.469
#
# Processing path from 4845 to 64885:
# Valid path found with 145 edges and total weight 327.413
#
# Processing path from 4845 to 40538:
# Edge (43161, 43162) has invalid weight: nan
#
# Processing path from 4845 to 16529:
# Valid path found with 56 edges and total weight 107.283
#
# Processing path from 4845 to 42597:
# Valid path found with 154 edges and total weight 313.140
#
# Processing path from 4845 to 29937:
# Valid path found with 123 edges and total weight 224.821
#
# Processing path from 4845 to 15110:
# Edge (14885, 14583) has invalid weight: nan
#
# Processing path from 4845 to 17120:
# Valid path found with 87 edges and total weight 177.244
#
# Processing path from 4845 to 38262:
# Valid path found with 134 edges and total weight 291.285
#
# Processing path from 4845 to 29529:
# Valid path found with 52 edges and total weight 100.540
#
# Processing path from 4845 to 67809:
# Valid path found with 113 edges and total weight 255.751
#
# Processing path from 4845 to 10663:
# Valid path found with 52 edges and total weight 109.455
#
# Processing path from 4845 to 7598:
# Valid path found with 116 edges and total weight 211.582
#
# Processing path from 4845 to 14689:
# Error processing path 4845 to 14689: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 22652:
# Valid path found with 118 edges and total weight 237.009
#
# Processing path from 4845 to 4204:
# Valid path found with 52 edges and total weight 127.310
#
# Processing path from 4845 to 56214:
# Edge (54389, 54391) has invalid weight: nan
#
# Processing path from 4845 to 2694:
# Valid path found with 55 edges and total weight 117.739
#
# Processing path from 4845 to 19892:
# Valid path found with 48 edges and total weight 94.740
#
# Processing path from 4845 to 45488:
# Valid path found with 113 edges and total weight 215.199
#
# Processing path from 4845 to 21489:
# Valid path found with 111 edges and total weight 221.335
#
# Processing path from 4845 to 40756:
# Valid path found with 223 edges and total weight 485.057
#
# Processing path from 4845 to 54367:
# Error processing path 4845 to 54367: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 23022:
# Valid path found with 57 edges and total weight 122.466
#
# Processing path from 4845 to 40555:
# Error processing path 4845 to 40555: Contradictory paths found: negative weights?
#
# Processing path from 4845 to 10761:
# Valid path found with 101 edges and total weight 234.212
#
# Processing path from 4845 to 14498:
# Valid path found with 112 edges and total weight 220.878
#
# Processing path from 4845 to 4374:
# Valid path found with 29 edges and total weight 67.182
#
# Processing path from 4845 to 5486:
# Valid path found with 56 edges and total weight 127.517
#
# Processing path from 4845 to 42054:
# Valid path found with 157 edges and total weight 288.458
#
# Processing path from 4845 to 42814:
# Valid path found with 186 edges and total weight 375.536
#
# Processing path from 4845 to 13005:
# Valid path found with 137 edges and total weight 280.309
#
# ...
#
# Processing path from 29150 to 66001:
# Valid path found with 185 edges and total weight 400.004
#
# Processing path from 29150 to 15352:
# Valid path found with 272 edges and total weight 527.461
#
# Processing path from 29150 to 35097:
# Edge (45609, 54032) has invalid weight: nan
#
# Processing path from 29150 to 13152:
# Valid path found with 195 edges and total weight 364.158
#
# Processing path from 29150 to 14977:
# Valid path found with 133 edges and total weight 249.938
#
# Processing path from 29150 to 28402:
# Valid path found with 39 edges and total weight 106.506
#
# Processing path from 29150 to 11659:
# Valid path found with 111 edges and total weight 219.221
#
# Processing path from 29150 to 64706:
# Edge (65991, 65989) has invalid weight: nan
#
# Processing path from 29150 to 44477:
# Valid path found with 104 edges and total weight 210.802
#
# Processing path from 29150 to 44458:
# Valid path found with 98 edges and total weight 193.884
#
# Processing path from 29150 to 71058:
# Error processing path 29150 to 71058: Contradictory paths found: negative weights?
#
# Processing path from 29150 to 2502:
# Valid path found with 106 edges and total weight 198.542
#
# Processing path from 29150 to 3395:
# Valid path found with 132 edges and total weight 242.776
#
# Processing path from 29150 to 2671:
# Valid path found with 103 edges and total weight 192.833
#
# Processing path from 29150 to 6889:
# Valid path found with 70 edges and total weight 128.813
#
# Processing path from 29150 to 4466:
# Valid path found with 82 edges and total weight 145.792
#
# Processing path from 29150 to 8057:
# Valid path found with 63 edges and total weight 119.074
#
# Processing path from 29150 to 22422:
# Valid path found with 211 edges and total weight 409.602
#
# Processing path from 29150 to 28235:
# Valid path found with 28 edges and total weight 64.154
#
# Processing path from 29150 to 67823:
# Edge (6103, 6104) has invalid weight: nan
#
# Processing path from 29150 to 46552:
# Valid path found with 265 edges and total weight 590.808
#
# Processing path from 29150 to 22539:
# Valid path found with 159 edges and total weight 282.435
#
# Processing path from 29150 to 42074:
# Valid path found with 165 edges and total weight 339.139
#
# Processing path from 29150 to 21349:
# Valid path found with 220 edges and total weight 428.263
#
# Processing path from 29150 to 2513:
# Valid path found with 115 edges and total weight 214.705
#
# Processing path from 29150 to 22457:
# Valid path found with 316 edges and total weight 631.933
#
# Processing path from 29150 to 11348:
# Valid path found with 72 edges and total weight 137.830
#
# Processing path from 29150 to 17155:
# Valid path found with 152 edges and total weight 291.794
#
# Processing path from 29150 to 35136:
# Valid path found with 77 edges and total weight 141.264
#
# Processing path from 29150 to 51413:
# Valid path found with 112 edges and total weight 230.815
#
# Processing path from 29150 to 35491:
# Valid path found with 115 edges and total weight 221.784
#
# Processing path from 29150 to 42592:
# Valid path found with 145 edges and total weight 308.314
#
# Processing path from 29150 to 20627:
# Valid path found with 152 edges and total weight 272.576
#
# Processing path from 29150 to 67854:
# Edge (67508, 67507) has invalid weight: nan
#
# Processing path from 29150 to 39834:
# Error processing path 29150 to 39834: Contradictory paths found: negative weights?
#
# Processing path from 29150 to 14179:
# Edge (54187, 54188) has invalid weight: nan
#
# Processing path from 29150 to 51329:
# Edge (52041, 53536) has invalid weight: nan
#
# Processing path from 29150 to 63849:
# Valid path found with 109 edges and total weight 196.867
#
# Processing path from 29150 to 15877:
# Error processing path 29150 to 15877: Contradictory paths found: negative weights?
#
# Processing path from 29150 to 28403:
# Valid path found with 40 edges and total weight 109.289
#
# Processing path from 29150 to 26504:
# Edge (14885, 14583) has invalid weight: nan
#
# Processing path from 29150 to 7413:
# Valid path found with 47 edges and total weight 87.297
#
# Processing path from 29150 to 17735:
# Valid path found with 96 edges and total weight 195.216
#
# Processing path from 29150 to 15488:
# Valid path found with 253 edges and total weight 483.165
#
# Processing path from 29150 to 7153:
# Error processing path 29150 to 7153: Contradictory paths found: negative weights?
#
# Processing path from 29150 to 35394:
# Valid path found with 108 edges and total weight 210.276
#
# Processing path from 29150 to 4831:
# Valid path found with 111 edges and total weight 204.332
#
# Processing path from 29150 to 20245:
# Valid path found with 251 edges and total weight 484.290
#
# Processing path from 29150 to 20913:
# Valid path found with 214 edges and total weight 398.071
#
# Processing path from 29150 to 42121:
# Valid path found with 135 edges and total weight 280.217
#
# Processing path from 29150 to 11006:
# Valid path found with 66 edges and total weight 118.806
#
# Processing path from 29150 to 11227:
# Valid path found with 95 edges and total weight 170.287
#
# Processing path from 29150 to 19890:
# Valid path found with 108 edges and total weight 225.261
#
# Processing path from 29150 to 35082:
# Valid path found with 53 edges and total weight 142.263
#
# Processing path from 29150 to 13263:
# Valid path found with 175 edges and total weight 322.406
#
# Processing path from 29150 to 28432:
# Valid path found with 34 edges and total weight 80.279
#
# Processing path from 29150 to 20613:
# Error processing path 29150 to 20613: Contradictory paths found: negative weights?
#
# Processing path from 29150 to 18436:
# Error processing path 29150 to 18436: Contradictory paths found: negative weights?
#
# Processing path from 29150 to 44377:
# Valid path found with 98 edges and total weight 194.525
#
# Processing path from 29150 to 70988:
# Error processing path 29150 to 70988: Contradictory paths found: negative weights?
#
# Processing path from 29150 to 55667:
# Valid path found with 121 edges and total weight 286.195
#
# Processing path from 29150 to 10566:
# Valid path found with 207 edges and total weight 414.868
#
# Processing path from 29150 to 22287:
# Error processing path 29150 to 22287: Contradictory paths found: negative weights?
#
# Processing path from 29150 to 11167:
# Valid path found with 73 edges and total weight 145.396
#
# Processing path from 29150 to 4180:
# Valid path found with 108 edges and total weight 205.431
#
# Processing path from 29150 to 44280:
# Valid path found with 106 edges and total weight 208.375
#
# Processing path from 29150 to 15401:
# Valid path found with 231 edges and total weight 439.443
#
# Processing path from 29150 to 7570:
# Valid path found with 92 edges and total weight 194.046
#
# Processing path from 29150 to 5313:
# Valid path found with 48 edges and total weight 102.548
#
# Processing path from 29150 to 29904:
# Valid path found with 59 edges and total weight 112.940
#
# Processing path from 29150 to 32782:
# Valid path found with 82 edges and total weight 166.148
#
# Processing path from 29150 to 39838:
# Valid path found with 169 edges and total weight 364.141
#
# Processing path from 29150 to 7632:
# Valid path found with 43 edges and total weight 85.772
#
# Processing path from 29150 to 11049:
# Valid path found with 56 edges and total weight 98.410
#
# Processing path from 29150 to 4328:
# Valid path found with 124 edges and total weight 231.099
#
# Processing path from 29150 to 2643:
# Valid path found with 109 edges and total weight 206.122
#
# Processing path from 29150 to 15496:
# Valid path found with 231 edges and total weight 437.960
#
# Processing path from 29150 to 64583:
# Valid path found with 141 edges and total weight 304.098
#
# Processing path from 29150 to 10481:
# Edge (11945, 8493) has invalid weight: nan
#
# Processing path from 29150 to 22537:
# Error processing path 29150 to 22537: Contradictory paths found: negative weights?
#
# Processing path from 29150 to 67108:
# Valid path found with 290 edges and total weight 742.179
#
# Processing path from 29150 to 11958:
# Valid path found with 105 edges and total weight 203.839
#
# Processing path from 29150 to 17193:
# Valid path found with 136 edges and total weight 254.091
#
# Processing path from 29150 to 48279:
# Edge (54389, 54391) has invalid weight: nan
#
# Processing path from 29150 to 3393:
# Valid path found with 144 edges and total weight 273.611
#
# Processing path from 29150 to 15814:
# Valid path found with 239 edges and total weight 583.298
#
# Processing path from 29150 to 14569:
# Edge (68508, 12261) has invalid weight: nan
#
# Processing path from 29150 to 17627:
# Valid path found with 86 edges and total weight 186.668
#
# Processing path from 29150 to 15025:
# Valid path found with 286 edges and total weight 560.715
#
# Processing path from 29150 to 15899:
# Valid path found with 244 edges and total weight 466.720
#
# Processing path from 29150 to 29247:
# Edge (5644, 5645) has invalid weight: nan
#
# Processing path from 29150 to 67808:
# Valid path found with 138 edges and total weight 279.605
#
# Processing path from 29150 to 32734:
# Valid path found with 33 edges and total weight 64.328
#
# Processing path from 29150 to 3037:
# Valid path found with 128 edges and total weight 241.085
#
# Processing path from 29150 to 73159:
# Valid path found with 355 edges and total weight 748.999
#
# Processing path from 29150 to 53409:
# Error processing path 29150 to 53409: Contradictory paths found: negative weights?
#
# Processing path from 29150 to 9146:
# Valid path found with 106 edges and total weight 229.148
#
# Processing path from 29150 to 35522:
# Valid path found with 25 edges and total weight 49.390
#
# Processing path from 29150 to 43930:
# Error processing path 29150 to 43930: Contradictory paths found: negative weights?
#
# Processing path from 29150 to 53474:
# Edge (52041, 53536) has invalid weight: nan
#
# Processing path from 29150 to 73286:
# Valid path found with 298 edges and total weight 646.661
#
# Processing path from 29150 to 24093:
# Valid path found with 185 edges and total weight 416.406
#
# Processing path from 29150 to 71269:
# Error processing path 29150 to 71269: Contradictory paths found: negative weights?
#
# Processing path from 29150 to 69258:
# Error processing path 29150 to 69258: Contradictory paths found: negative weights?
#
# Processing path from 29150 to 20244:
# Valid path found with 252 edges and total weight 487.397
#
# Processing path from 29150 to 64885:
# Valid path found with 242 edges and total weight 515.068
#
# Processing path from 29150 to 40538:
# Valid path found with 150 edges and total weight 282.508
#
# Processing path from 29150 to 16529:
# Valid path found with 123 edges and total weight 220.769
#
# Processing path from 29150 to 42597:
# Valid path found with 136 edges and total weight 281.622
#
# Processing path from 29150 to 29937:
# Valid path found with 114 edges and total weight 220.079
#
# Processing path from 29150 to 15110:
# Valid path found with 235 edges and total weight 445.677
#
# Processing path from 29150 to 17120:
# Valid path found with 154 edges and total weight 290.729
#
# Processing path from 29150 to 38262:
# Valid path found with 173 edges and total weight 372.867
#
# Processing path from 29150 to 29529:
# Valid path found with 21 edges and total weight 51.847
#
# Processing path from 29150 to 67809:
# Valid path found with 293 edges and total weight 569.114
#
# Processing path from 29150 to 10663:
# Valid path found with 122 edges and total weight 231.300
#
# Processing path from 29150 to 7598:
# Valid path found with 78 edges and total weight 150.313
#
# Processing path from 29150 to 14689:
# Error processing path 29150 to 14689: Contradictory paths found: negative weights?
#
# Processing path from 29150 to 22652:
# Valid path found with 211 edges and total weight 398.519
#
# Processing path from 29150 to 4204:
# Valid path found with 103 edges and total weight 199.320
#
# Processing path from 29150 to 56214:
# Edge (54389, 54391) has invalid weight: nan
#
# Processing path from 29150 to 2694:
# Valid path found with 124 edges and total weight 227.994
#
# Processing path from 29150 to 19892:
# Valid path found with 145 edges and total weight 282.505
#
# Processing path from 29150 to 45488:
# Valid path found with 104 edges and total weight 210.457
#
# Processing path from 29150 to 21489:
# Valid path found with 217 edges and total weight 424.466
#
# Processing path from 29150 to 40756:
# Valid path found with 162 edges and total weight 324.745
#
# Processing path from 29150 to 54367:
# Valid path found with 120 edges and total weight 229.337
#
# Processing path from 29150 to 23022:
# Valid path found with 126 edges and total weight 232.720
#
# Processing path from 29150 to 40555:
# Valid path found with 201 edges and total weight 432.846
#
# Processing path from 29150 to 10761:
# Valid path found with 293 edges and total weight 564.959
#
# Processing path from 29150 to 14498:
# Valid path found with 205 edges and total weight 382.387
#
# Processing path from 29150 to 4374:
# Valid path found with 107 edges and total weight 202.724
#
# Processing path from 29150 to 5486:
# Valid path found with 94 edges and total weight 195.031
#
# Processing path from 29150 to 42054:
# Valid path found with 148 edges and total weight 283.716
#
# Processing path from 29150 to 42814:
# Error processing path 29150 to 42814: Contradictory paths found: negative weights?
#
# Processing path from 29150 to 13005:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 od_path_dataset = calculate_od_paths(G_workday_48, origins, destinations)
#       3 # # Analyze the paths
#       4 # stats = analyze_paths(od_path_dataset)
#       5 # print("\nPath Statistics:")
#    (...)
#      11 # for path_info in od_path_dataset[:5]:  # print first 5 paths
#      12 #     print("\n" + format_path_for_printing(path_info))
#
# Cell In[19], line 85, in calculate_od_paths(G, origins, destinations, max_pairs)
#      81     continue
#      83 try:
#      84     # Find shortest path
# ---> 85     path = nx.shortest_path(G, o, d, weight='weight')
#      87     # Validate path edges
#      88     skip_path = False
#
# File d:\Thesis\python_venv\thesis_venv\Lib\site-packages\networkx\utils\backends.py:412, in _dispatch.__call__(self, backend, *args, **kwargs)
#     409 def __call__(self, /, *args, backend=None, **kwargs):
#     410     if not backends:
#     411         # Fast path if no backends are installed
# --> 412         return self.orig_func(*args, **kwargs)
#     414     # Use `backend_name` in this function instead of `backend`
#     415     backend_name = backend
#
# File d:\Thesis\python_venv\thesis_venv\Lib\site-packages\networkx\algorithms\shortest_paths\generic.py:175, in shortest_path(G, source, target, weight, method)
#     173     paths = nx.bidirectional_shortest_path(G, source, target)
#     174 elif method == "dijkstra":
# --> 175     _, paths = nx.bidirectional_dijkstra(G, source, target, weight)
#     176 else:  # method == 'bellman-ford':
#     177     paths = nx.bellman_ford_path(G, source, target, weight)
#
# File d:\Thesis\python_venv\thesis_venv\Lib\site-packages\networkx\utils\backends.py:412, in _dispatch.__call__(self, backend, *args, **kwargs)
#     409 def __call__(self, /, *args, backend=None, **kwargs):
#     410     if not backends:
#     411         # Fast path if no backends are installed
# --> 412         return self.orig_func(*args, **kwargs)
#     414     # Use `backend_name` in this function instead of `backend`
#     415     backend_name = backend
#
# File d:\Thesis\python_venv\thesis_venv\Lib\site-packages\networkx\algorithms\shortest_paths\weighted.py:2410, in bidirectional_dijkstra(G, source, target, weight)
#    2406     return (finaldist, finalpath)
#    2408 for w, d in neighs[dir][v].items():
#    2409     # weight(v, w, d) for forward and weight(w, v, d) for back direction
# -> 2410     cost = weight(v, w, d) if dir == 0 else weight(w, v, d)
#    2411     if cost is None:
#    2412         continue
#
# File d:\Thesis\python_venv\thesis_venv\Lib\site-packages\networkx\algorithms\shortest_paths\weighted.py:78, in _weight_function.<locals>.<lambda>(u, v, data)
#      76 if G.is_multigraph():
#      77     return lambda u, v, d: min(attr.get(weight, 1) for attr in d.values())
# ---> 78 return lambda u, v, data: data.get(weight, 1)
#
# KeyboardInterrupt:

# %%
from matplotlib.colors import LinearSegmentedColormap

def visualize_od_paths(G, path_dataset, figsize=(15, 10), node_size=100, 
                      edge_width_scale=2, title="Network OD Paths Visualization"):
    """
    Visualize the network with OD paths highlighted based on their weights.
    
    Parameters:
    -----------
    G : networkx.Graph
        Original network graph
    path_dataset : list
        List of paths with weights from calculate_od_paths function
    figsize : tuple, default=(15, 10)
        Figure size
    node_size : int, default=100
        Size of nodes in visualization
    edge_width_scale : float, default=2
        Scaling factor for edge widths
    title : str, default="Network OD Paths Visualization"
        Title of the plot
    """
    # Create a new figure
    plt.figure(figsize=figsize)
    
    # Create a copy of the graph for visualization
    G_viz = G.copy()
    
    # Calculate edge frequencies and total weights
    edge_weights = {}
    edge_frequencies = {}
    
    # Collect all weights for normalization
    all_weights = []
    
    # Process each path
    for path_info in path_dataset:
        for edge_info in path_info['path']:
            edge = edge_info['edge']
            weight = edge_info['weight']
            
            # Update edge frequencies
            edge_frequencies[edge] = edge_frequencies.get(edge, 0) + 1
            
            # Update cumulative weights
            if edge not in edge_weights:
                edge_weights[edge] = weight
            else:
                edge_weights[edge] = max(edge_weights[edge], weight)
            
            all_weights.append(weight)
    
    # Normalize weights for visualization
    max_weight = max(all_weights)
    min_weight = min(all_weights)
    weight_range = max_weight - min_weight
    
    # Create positions for nodes (you might want to adjust the layout algorithm)
    pos = nx.spring_layout(G_viz, k=1/np.sqrt(len(G_viz.nodes())), iterations=50)
    
    # Draw the base network (edges not in paths)
    nx.draw_networkx_edges(G_viz, pos, 
                          edgelist=[(u, v) for (u, v) in G_viz.edges() if (u, v) not in edge_weights],
                          edge_color='lightgray',
                          width=0.5,
                          alpha=0.3)
    
    # Create custom colormap
    colors = ['lightblue', 'blue', 'darkblue']
    n_bins = 100
    cmap = LinearSegmentedColormap.from_list("custom", colors, N=n_bins)
    
    # Draw edges in paths with varying width and color
    for edge, weight in edge_weights.items():
        # Normalize weight for color mapping
        norm_weight = (weight - min_weight) / weight_range if weight_range > 0 else 0.5
        
        # Calculate edge width based on frequency
        width = np.log1p(edge_frequencies[edge]) * edge_width_scale
        
        # Draw the edge
        nx.draw_networkx_edges(G_viz, pos,
                             edgelist=[edge],
                             edge_color=[norm_weight],
                             edge_cmap=cmap,
                             width=width)
    
    # Identify origins and destinations
    origins = set(path_info['origin'] for path_info in path_dataset)
    destinations = set(path_info['destination'] for path_info in path_dataset)
    
    # Draw different types of nodes
    # Regular nodes
    regular_nodes = [node for node in G_viz.nodes() 
                    if node not in origins and node not in destinations]
    if regular_nodes:
        nx.draw_networkx_nodes(G_viz, pos, 
                             nodelist=regular_nodes,
                             node_color='lightgray',
                             node_size=node_size)
    
    # Origin nodes
    if origins:
        nx.draw_networkx_nodes(G_viz, pos, 
                             nodelist=list(origins),
                             node_color='green',
                             node_size=node_size*1.5)
    
    # Destination nodes
    if destinations:
        nx.draw_networkx_nodes(G_viz, pos, 
                             nodelist=list(destinations),
                             node_color='red',
                             node_size=node_size*1.5)
    
    # Add labels for important nodes
    important_nodes = origins.union(destinations)
    labels = {node: str(node) for node in important_nodes}
    nx.draw_networkx_labels(G_viz, pos, labels, font_size=8)
    
    # Add a colorbar
    sm = plt.cm.ScalarMappable(cmap=cmap)
    sm.set_array([])
    plt.colorbar(sm, label='Edge Weight')
    
    # Add legend
    plt.plot([], [], 'go', label='Origins', markersize=8)
    plt.plot([], [], 'ro', label='Destinations', markersize=8)
    plt.legend()
    
    plt.title(title)
    plt.axis('off')
    
    # Add text with statistics
    stats_text = (
        f"Total Paths: {len(path_dataset)}\n"
        f"Origins: {len(origins)}\n"
        f"Destinations: {len(destinations)}\n"
        f"Active Edges: {len(edge_weights)}"
    )
    plt.text(0.02, 0.98, stats_text, 
             transform=plt.gca().transAxes,
             verticalalignment='top',
             bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
    
    plt.tight_layout()
    
    return plt.gcf()

# Example usage:
"""
# Calculate paths
od_path_dataset = calculate_od_paths(G_workday_48)

# Create visualization
fig = visualize_od_paths(G_workday_48, od_path_dataset)
plt.show()

# Save the figure if needed
# fig.savefig('network_od_paths.png', dpi=300, bbox_inches='tight')
"""

def create_interactive_network_visualization(G, path_dataset):
    """
    Create an interactive HTML visualization of the network using Pyvis
    Useful for exploring large networks
    """
    from pyvis.network import Network
    
    # Create a new network
    net = Network(notebook=True, height="750px", width="100%")
    
    # Calculate edge weights and frequencies
    edge_weights = {}
    edge_frequencies = {}
    for path_info in path_dataset:
        for edge_info in path_info['path']:
            edge = edge_info['edge']
            weight = edge_info['weight']
            edge_frequencies[edge] = edge_frequencies.get(edge, 0) + 1
            if edge not in edge_weights:
                edge_weights[edge] = weight
            else:
                edge_weights[edge] = max(edge_weights[edge], weight)
    
    # Add nodes
    origins = set(path_info['origin'] for path_info in path_dataset)
    destinations = set(path_info['destination'] for path_info in path_dataset)
    
    for node in G.nodes():
        color = 'lightgray'
        if node in origins:
            color = 'green'
        elif node in destinations:
            color = 'red'
        
        net.add_node(node, label=str(node), color=color)
    
    # Add edges
    max_weight = max(edge_weights.values())
    for (u, v) in G.edges():
        if (u, v) in edge_weights:
            weight = edge_weights[(u, v)]
            frequency = edge_frequencies[(u, v)]
            width = np.log1p(frequency) * 2
            value = weight / max_weight  # normalized weight for color intensity
            
            net.add_edge(u, v, width=width, value=value, title=f"Weight: {weight:.2f}")
        else:
            net.add_edge(u, v, color='lightgray', width=0.5)
    
    # Set physics layout options
    net.toggle_physics(True)
    net.show_buttons(filter_=['physics'])
    
    return net

# Example usage for interactive visualization:
"""
# Create interactive network
net = create_interactive_network_visualization(G_workday_48, od_path_dataset)
net.show('network_visualization.html')
"""
