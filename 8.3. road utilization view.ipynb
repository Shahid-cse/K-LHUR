# %%
import pandas as pd

# %%
output_dir = 'D:/Thesis/files_output_dir/output_utilization/'

# %%
level1_road_history_workday_utility = pd.read_csv(output_dir + 'level1_road_history_workday_utilization_tune_AHP.csv')
level2_road_history_workday_utility = pd.read_csv(output_dir + 'level2_road_history_workday_utilization_tune_AHP.csv')
level3_road_history_workday_utility = pd.read_csv(output_dir + 'level3_road_history_workday_utilization_tune_AHP.csv')

# %%
level1_road_history_holiday_utility = pd.read_csv(output_dir + 'level1_road_history_holiday_utilization_tune_AHP.csv')
level2_road_history_holiday_utility = pd.read_csv(output_dir + 'level2_road_history_holiday_utilization_tune_AHP.csv')
level3_road_history_holiday_utility = pd.read_csv(output_dir + 'level3_road_history_holiday_utilization_tune_AHP.csv')

# %%
utility = level1_road_history_workday_utility[['road_id','time','avg_speed','volume','theta','vc', 'qc', 'Uq', 'Uv', 'Uq_norm', 'Uv_norm', 'theta_norm',
       'utilization' ]]
utility[(utility['utilization'] > 0.7)].head(10)
# Out:
#        road_id  time  avg_speed  volume  theta         vc    qc        Uq  \
# 19443     4081    42  10.318195   100.5    2.0  12.186243  40.8  2.463235
# 19444     4081    43   7.486058   100.5    2.0  12.186243  40.8  2.463235
# 19445     4081    44   5.385758   100.5    2.0  12.186243  40.8  2.463235
# 19446     4081    45   4.656354   100.5    2.0  12.186243  40.8  2.463235
# 19447     4081    46   4.084639   100.5    2.0  12.186243  40.8  2.463235
# 19448     4081    47   3.955736   100.5    2.0  12.186243  40.8  2.463235
# 19449     4081    48   3.986831   100.5    2.0  12.186243  40.8  2.463235
# 19450     4081    49   4.035281   100.5    2.0  12.186243  40.8  2.463235
# 19451     4081    50   4.261284   100.5    2.0  12.186243  40.8  2.463235
# 19452     4081    51   4.456765   100.5    2.0  12.186243  40.8  2.463235
#
#              Uv   Uq_norm   Uv_norm  theta_norm  utilization
# 19443  0.846708  2.463235  0.846708         2.0     0.850026
# ...

# %%
utility = level1_road_history_workday_utility[['road_id','time','avg_speed','volume','theta','vc', 'qc', 'Uq', 'Uv', 'Uq_norm', 'Uv_norm', 'theta_norm',
       'utilization' ]]
utility[(utility['time'] == 48) & (utility['utilization'] > 0.1) & (utility['road_id']== 2471)].head()
# Out:
#        road_id  time  avg_speed  volume  theta        vc      qc       Uq  \
# 12620     2471    48  14.039541   100.5    2.0  12.46895  75.825  1.32542
#
#             Uv  Uq_norm  Uv_norm  theta_norm  utilization
# 12620  1.12596  1.32542  1.12596         2.0     0.528775

# %%
utility = level1_road_history_holiday_utility[['road_id','time','avg_speed','volume','theta','vc', 'qc', 'Uq', 'Uv', 'Uq_norm', 'Uv_norm', 'theta_norm',
       'utilization' ]]
utility[(utility['time'] == 48) & (utility['utilization'] > 0.1) & (utility['road_id']== 2471)].head()
# Out:
#        road_id  time  avg_speed  volume  theta         vc     qc        Uq  \
# 11570     2471    48  15.833725  86.475    0.0  15.910411  100.5  0.860448
#
#             Uv   Uq_norm  Uv_norm  theta_norm  utilization
# 11570  0.99518  0.860448  0.99518         0.0     0.264314

# %%
utility = level2_road_history_workday_utility[['road_id','time','avg_speed','volume','theta','vc', 'qc', 'Uq', 'Uv', 'Uq_norm', 'Uv_norm', 'theta_norm',
       'utilization' ]]
utility[(utility['utilization'] > 0.6) & (utility['time'] == 48)][0:10]
# Out:
#          road_id  time  avg_speed  volume  theta        vc   qc      Uq  \
# 12574        283    48   8.729779  20.925    2.0  7.176015  1.8  11.625
# 2358144    61833    48   8.783275  20.100    2.0  7.780799  1.2  16.750
# 2659644    69447    48  10.097469  20.100    2.0  9.459752  1.2  16.750
#
#                Uv  Uq_norm   Uv_norm  theta_norm  utilization
# 12574    1.216522   11.625  1.216522         2.0     0.699549
# 2358144  1.128840   16.750  1.128840         2.0     0.987457
# 2659644  1.067414   16.750  1.067414         2.0     0.986027

# %%
utility = level2_road_history_workday_utility[['road_id','time','avg_speed','volume','theta','vc', 'qc', 'Uq', 'Uv', 'Uq_norm', 'Uv_norm', 'theta_norm',
       'utilization' ]]
utility[(utility['time'] == 48) & (utility['utilization'] > 0.1) & (utility['road_id']== 6502)].head()
# Out:
#         road_id  time  avg_speed  volume  theta       vc    qc   Uq        Uv  \
# 273847     6502    48   9.101695    20.1    2.0  5.10556  20.1  1.0  1.782702
#
#         Uq_norm   Uv_norm  theta_norm  utilization
# 273847      1.0  1.782702         2.0     0.111612

# %%
utility = level2_road_history_holiday_utility[['road_id','time','avg_speed','volume','theta','vc', 'qc', 'Uq', 'Uv', 'Uq_norm', 'Uv_norm', 'theta_norm',
       'utilization' ]]
utility[(utility['time'] == 48) & (utility['utilization'] > 0.1) & (utility['road_id']== 6502)].head()
# Out:
# Empty DataFrame
# Columns: [road_id, time, avg_speed, volume, theta, vc, qc, Uq, Uv, Uq_norm, Uv_norm, theta_norm, utilization]
# Index: []

# %%
utility = level3_road_history_workday_utility[['road_id','time','avg_speed','volume','theta','vc', 'qc', 'Uq', 'Uv', 'Uq_norm', 'Uv_norm', 'theta_norm',
       'utilization' ]]
utility[utility['utilization']>.7].head(10)
# Out:
#          road_id  time  avg_speed  volume  theta        vc     qc        Uq  \
# 1626073    26476    19   0.648742    7.55    1.0  4.364954  0.485  15.56701
# 1626085    26476   109   6.267806    7.55    0.0  4.364954  0.485  15.56701
# 1626088    26476   116   2.259982    7.55    1.0  4.364954  0.485  15.56701
# 1626092    26476   120   2.893229    7.55    1.0  4.364954  0.485  15.56701
# 1626093    26476   122   5.233912    7.55    0.0  4.364954  0.485  15.56701
# 1626102    26476   140   7.397747    7.55    0.0  4.364954  0.485  15.56701
# 1626103    26476   141   5.882659    7.55    0.0  4.364954  0.485  15.56701
# 1626104    26476   143   6.973899    7.55    0.0  4.364954  0.485  15.56701
# 1703983    27653    38   0.195341   15.10    1.0  3.036157  0.970  15.56701
# 1703992    27653   117   4.932527   15.10    0.0  3.036157  0.970  15.56701
#
#                Uv   Uq_norm   Uv_norm  theta_norm  utilization
# 1626073  0.148625  15.56701  0.148625         1.0     0.947044
# ...

# %%
utility = level3_road_history_workday_utility[['road_id','time','avg_speed','volume','theta','vc', 'qc', 'Uq', 'Uv', 'Uq_norm', 'Uv_norm', 'theta_norm',
       'utilization' ]]
utility[(utility['time'] == 48) & (utility['utilization'] > 0.1) & (utility['road_id']== 29933)].head()
# Out:
#          road_id  time  avg_speed  volume  theta        vc     qc   Uq  \
# 1830256    29933    48   9.040594   1.135    2.0  5.795121  1.135  1.0
#
#                Uv   Uq_norm  Uv_norm  theta_norm  utilization
# 1830256  1.560036  0.060361  0.38732         1.0     0.567048

# %%
utility = level3_road_history_holiday_utility[['road_id','time','avg_speed','volume','theta','vc', 'qc', 'Uq', 'Uv', 'Uq_norm', 'Uv_norm', 'theta_norm',
       'utilization' ]]
utility[(utility['time'] == 48) & (utility['utilization'] > 0.1) & (utility['road_id']== 29933)].head()
# Out:
#          road_id  time  avg_speed  volume  theta         vc    qc   Uq  \
# 1427602    29933    48  11.223751    4.85    2.0  10.191569  4.85  1.0
#
#                Uv   Uq_norm   Uv_norm  theta_norm  utilization
# 1427602  1.101278  0.060361  0.235316         1.0     0.512146
